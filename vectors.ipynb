# %%
import numpy as np
a=np.array([7,2,3,4])
b=np.array([5,9,6,7])
c=np.array([7,8,3,2])
print(a+b+c)
# Out:
# [19 19 12 13]

# %%
x=np.array([
[1,6],
[9,6],
[4,8],
[2,6]
])

# %%
np.dot([8,2],[7,5])
# Out:
# np.int64(66)

# %%
import numpy as np
scores=[7.0,8.4,8.3,8.1]
print(np.mean(scores))

# %%
import random
outcomes=["spam",["not spam"]]
print(random.choice(outcomes))
# Out:
# ['not spam']

# %%
w=5
ir=0.9
for i in range(5):
  w=w-ir*2*w
  print(w)
# Out:
# -4.0
# 3.2
# -2.5600000000000005
# 2.048000000000001
# -1.6384000000000007
