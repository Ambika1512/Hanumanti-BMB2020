# %%
name=hanumanti
age=21
print("hello",name)
print("you are,"age,"years old")
# Out:
#   File "/tmp/ipython-input-2242896743.py", line 4
#     print("you are,"age,"years old")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
name='hanumanti'
age=21
print("hello",name)
print("you are,",age,"years old")
# Out:
# hello hanumanti
# you are, 21 years old

# %%
x=5
y=2
z=x+y*3
print(z)
# Out:
# 11

# %%
mark1=60
mark2=80
mark3=100
print("total=",total)
print("average=",average)
# Out:
# total= 240
# average= 80

# %%
a=5
b=10
c=a+b
print(c)
# Out:
# 15

# %%
mark=int(input("enter mark"))
if mark>=90:
    print("grade a")
elif mark>=75:
    print("grade b")
else:
    print("grade c")
# Out:
# enter mark92
# grade a

# %%
num = int(input("enter number"))
if num%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# enter number3
# odd number

# %%
age=int(input("enter age"))
if age > 12 or age > 60:
    print("discount")
else:
    print("no discount")
# Out:
# enter age30
# discount

# %%
if num%4==0:
    print("leaf year")
else:
    print("no leaf year")
# Out:
# no leaf year

# %%
n =int(input("enter n:"))
total=0
for i in range(1 ,n+1):
    total=total+i
print("sum=", total)
# Out:
# enter n:5
# sum= 15

# %%
rows=int(input("enter number of rows"))
for i in range(1,rows+1):
    print("*"*i)
    print()
# Out:
# enter number of rows4
# *
#
# **
#
# ***
#
# ****

# %%
marks=[56,78,90,45,88]
max_marks=max(marks)
total=0
count=0 # Initialize count
for mark in marks:
    total=total+mark
average=total/len(marks)
for mark in marks:
    if mark>=60:
        count=count+1
print("average=",average)
print("max marks=",max_marks)
print("count>=60:",count)
# Out:
# average= 71.4
# max marks= 90
# count>=60: 3

# %%
numbers=[10,-3,5,0,8,-2]
count=0
for n in numbers:
    if n>0:
        count+=1
        print("count=",count)
# Out:
# count= 1
# count= 2
# count= 3

# %%
def average_marks(marks_list):
  total=0
  for mark in marks_list:
    total=total+mark
  average=total/len(marks_list)
  return average

data=[60,70,80]
print("average=", average_marks(data))
# Out:
# average= 70.0

# %%
fee=int(input("enter base fee"))
age=int(input("enter age"))
if age<12:
  final_fee=fee*0.5
elif age>60:
  final_fee=fee*0.7
else:
  final_fee=fee
print("final fee=",final_fee)
# Out:
# enter base fee50
# enter age11
# final fee= 25.0
