# %%
nitrogen = float(input("enter soil nitrogen level (mg/kg):"))
print("nitrogen recommendation")

if nitrogen < 100:
    print("low nitrogen, needs addition \n cost = 2000")
elif 100 <= nitrogen <= 250:
    print("medium nitrogen \n cost = 1000")
else:
    print("high nitrogen, no addition needed \n cost = 0")
# Out:
# enter soil nitrogen level (mg/kg):150
# nitrogen recommendation
# medium nitrogen
#  cost = 1000

# %%
crop = input("enter crop type (rice/wheat/sugarcane):")
moisture = float(input("enter soil moisture (%):"))
print("\n irrigation recommendation")

if crop == "rice":
    if moisture < 50:
        print("rice needs frequent irrigation")
    elif moisture < 60:
        print("rice needs moderate irrigation")
    else:
        print("no irrigation needed for rice")

elif crop == "wheat":
    if moisture < 40:
        print("wheat needs frequent irrigation")
    elif moisture < 30: # Note: Logic in screenshot has <40 then <30
        print("wheat needs moderate irrigation")
    else:
        print("no irrigation needed for wheat")

elif crop == "sugarcane":
    if moisture < 70:
        print("sugarcane needs frequent irrigation")
    elif moisture < 60:
        print("sugarcane needs moderate irrigation")
    else:
        print("no irrigation needed for sugarcane")
else:
    print("Unknown crop type. Cannot provide irrigation recommendation.")
# Out:
# enter crop type (rice/wheat/sugarcane):wheat
# enter soil moisture (%):40
#
#  irrigation recommendation
# no irrigation needed for wheat

# %%
pest_per_plant = int(input("enter pest/plant"))
damage_percent = int(input("enter damage percent"))
temperature = int(input("enter temp"))
humidity = int(input("enter humidity"))

if (pest_per_plant < 5 and damage_percent < 10 and temperature < 20 and humidity < 20):
    print("severity level: low \n recom:monitor monthly")
elif (5 <= pest_per_plant <= 15 and 10 <= damage_percent <= 25 and 21 <= temperature <= 40 and 21 <= humidity <= 80):
    print("severity level:medium \n recom:monitor daily \n cost:500")
else:
    print("severity level:high \n recom:monitor regularly \n cost:1000")

# %%
pest_per_plant = int(input("enter pest/plant"))
damage_percent = int(input("enter damage percent"))
temperature = int(input("enter temp"))
humidity = int(input("enter humidity"))

if (pest_per_plant < 5 and damage_percent < 10 and temperature < 20 and humidity < 20):
    print("severity level: low \n recom:monitor monthly")
elif (5 <= pest_per_plant <= 15 and 10 <= damage_percent <= 25 and 21 <= temperature <= 40 and 21 <= humidity <= 80):
    print("severity level:medium \n recom:monitor daily \n cost:500")
else:
    print("severity level:high \n recom:monitor regularly \n cost:1000")

# %%
crop=input("Enter crop name")
soilmoisture=int(input("Enter the moisture"))
temp=input("Enter the temperature")
print(f"crop:{crop}, soilmoisture:{soilmoisture},temp:{temp}")
if crop == "rice":
    if (soilmoisture < 60) and (temp == "hot"):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is hot \n Estimated water time:50min")
    elif (soilmoisture < 50) and ((temp == "moderate") or (temp == "cool")):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is moderate or cool \n Estimated water time:30min")
    else:
        print("Do not irrigate")
if crop == "Wheat":
      if(soilmoisture < 40) and (temp == "hot"):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is hot \n Estimated water time:50min")
      elif(soilmoisture <= 30) and ((temp == "moderate") or (temp == "cool")):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is moderate or cool \n Estimated water time:30min")
      else:
        print("Do not irrigate")
if crop == "sugarcane":
      if(soilmoisture < 70) and (temp == "hot"):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is hot \n Estimated water time:50min")
      elif(soilmoisture < 60) and ((temp == "moderate") or (temp == "cool")):
        print("Decision:IRRIGATE NOW \n Reason:soil moisture is low and temperature is moderate or cool \n Estimated water time:30min")
      else:
        print("Do not irrigate")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1457657807.py in <cell line: 0>()
# ----> 1 crop=input("Enter crop name")
#       2 soilmoisture=int(input("Enter the moisture"))
#       3 temp=input("Enter the temperature")
#       4 print(f"crop:{crop}, soilmoisture:{soilmoisture},temp:{temp}")
#       5 if crop == "rice":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
rf=input("enter rf in mm")
temp=input("enter temp in degree")
s_q=input("enter soil status")
yield=0
base yield=40
print(f"rf:{rf},temp:{temp},s_q:{s_q}")
if rf>600:
  yield+=(rf-600)//10*2
elif rf<400:
  yield-=(rf-400)//10*2
if temp<25:
  yield-=(temp-25)
elif temp>30:
  yield+=(temp-30)
if s-q<80:
  yield-=(s-q-80)*1
elif s-q>100:
  yield+=(s-q-100)*1
final yield=yield+base yield
print(f"final yield:{final yield}")
# Out:
#   File "/tmp/ipython-input-171624933.py", line 4
#     yield=0
#     ^
# SyntaxError: assignment to yield expression not possible

# %% [markdown]
# # Task
# Rename the variable `yield` to `predicted_yield` throughout the provided code, convert the input values for `rf`, `temp`, and `s_q` from strings to appropriate numeric types, correct the variable `s-q` to `s_q` in the `if` conditions, and then apply rainfall, temperature, and soil quality adjustments proportionally to the `predicted_yield` to make the crop yield calculator functional and accurate.

# %% [markdown]
# ## Rename 'yield' variable
#
# ### Subtask:
# Rename the variable `yield` to a non-reserved keyword, such as `predicted_yield`, throughout the code to resolve the `SyntaxError`.

# %% [markdown]
# **Reasoning**:
# The subtask explicitly asks to rename the variable `yield` to `predicted_yield` to resolve a `SyntaxError`. Additionally, other syntax issues such as `base yield`, `s-q`, and `final yield` need to be corrected for the code to run properly. Input variables `rf`, `temp`, and `s_q` also need type conversion to `float` or `int` for numerical comparisons and calculations.

# %%
rf = float(input("enter rf in mm"))
temp = int(input("enter temp in degree"))
s_q = int(input("enter soil status"))

predicted_yield = 0
base_yield = 40

print(f"rf:{rf},temp:{temp},s_q:{s_q}")

if rf > 600:
  predicted_yield += (rf - 600) // 10 * 2
elif rf < 400:
  predicted_yield -= (rf - 400) // 10 * 2

if temp < 25:
  predicted_yield -= (25 - temp)
elif temp > 30:
  predicted_yield += (temp - 30)

if s_q < 80:
  predicted_yield -= (80 - s_q) * 1
elif s_q > 100:
  predicted_yield += (s_q - 100) * 1

final_yield = predicted_yield + base_yield
print(f"final yield:{final_yield}")
