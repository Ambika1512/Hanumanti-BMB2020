# %%
file=open("attendance.txt","w")
file.write("\n hanumati \n ashwini \n priyanshu \n tejeev \n raagu")
file.close()

# %%
file=open("attendance.txt","r")
content=file.read()
print(content)
file.close()
# Out:
#  hanumati
#  ashwini
#  priyanshu
#  tejeev
#  raagu

# %%
file=open("expence.txt","w")
file.write("\n 2026-01-08,$4,lunch,food \n 2026-01-08,$2,snacks,food")
file.close()

# %%
file=open("practice.txt","w")
file.write("\n learning python \n learning string")
file.close()

# %%
file=open("practice.txt","r")
content=file.read()
print(content)
file.close()
# Out:
#  learning python
#  learning string

# %%
file=open("practice.txt","a")
file.write("\n hello python!")
file.close()

# %%
file=open("practice.txt","r")
content=file.read()
print(content)
file.close()
# Out:
#  learning python
#  learning string
#  hello python!
