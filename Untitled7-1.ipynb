# %%
name="Bengalure"
print(len(name))
# Out:
# 9

# %%
word="collage"
print(word[-2])
# Out:
# g

# %%
text="python"
text=text.title()
print(text)
# Out:
# Python

# %%
text="apple,""banana"
print(text.count("a"))
# Out:
# 4

# %%
text="banana"
print(text.count("b"))
print(text.count("a"))
print(text.count("c"))
# Out:
# 1
# 3
# 0

# %%
numbers=int(input("enter a negative number"))
print(numbers)
# Out:
# enter a negative number-1
# -1

# %%
word="amma"
print(word[0:4])
# Out:
# amma

# %%
vowels = "aeiouAEIOU"
text="my name is hanumanti"
vowel_count = 0
for char in text:
    if char in vowels:
        vowel_count += 1
print(vowel_count)
# Out:
# 7

# %%
word="my name is hanumanti and age is 21"
print(word.count("is"))
# Out:
# 2
