# %%
word="hanumanti"
print(word[5])
print(word[3])
print(word[6])
print(word[4])
# Out:
# a
# u
# n
# m

# %%
word="hanumanti"
print(word[0:5])
# Out:
# hanum

# %%
name="chintamani"
print(len(name))
# Out:
# 10

# %%
"kumar RAJ".upper()
# Out:
# 'KUMAR RAJ'

# %%
"kumar raj".lower()
# Out:
# 'kumar raj'

# %%
data="python"
print(data.strip())
# Out:
# python

# %%
msg= "i like java"
print(msg.replace("java","python"))
# Out:
# i like python

# %%
email="user@gmail.com"
print("@" in email)
# Out:
# True

# %%
sentence="python is very easy"
words=sentence.split()
print(words)
# Out:
# ['python', 'is', 'very', 'easy']

# %%
words=["python","is","fun"]
print("".join(words))
# Out:
# pythonisfun
