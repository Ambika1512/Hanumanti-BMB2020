# %%
a=10
if(a>5):
 print('10 is greater than 5')

# %%
day="tuesday"
if(day=="saturday"):
  print("color dress")
else:
  print("uniform")

# %%
a=10
b=20
if(a>b):
  print("a is greater than b")
else:
   print("b is greater than a")

# %%
name="ashwini"
age=20
print("My name is",name,"and age is",age)

# %%
a=10
b=20
print("numbers are",a,"and",b)

# %%
temperature=int(input("enter temeprature in degree celsius"))
if(temperature>=25):
  print("suitable for crop growth")
else:
  print("not suitable for crop growth")

# %%
rainfall =int(input("enter trainfall in mm"))
if(rainfall>=500):
  print("suitable for rice")
else:
  print("not suitable for millets")

# %%
name="hanuanti"
age=20
print("My name is {} and age is {}".format (name,age))
