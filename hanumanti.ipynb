# %%
import numpy as np
scores=[70,80,90,]
print(np.mean(scores))
# Out:
# 80.0

# %%
import numpy as np
cricket_score=[20,17,15,100]
median_score=np.median(cricket_score)
print(f"median:{median_score}")
# Out:
# median:18.5

# %%
import numpy as np
quiz_score=[10,20,30,40]
print(np.std(quiz_score))
# Out:
# 11.180339887498949

# %%
import numpy as np
cricket_scores=[12,15,17,100]
median_score=np.median(cricket_scores)
print(f"median={median_score}")
# Out:
# median=16.0

# %%
from statistics import mode
votes=[1,2,2,4,4,4,5,5,6,6]
most_common=mode(votes)
print(most_common)
# Out:
# 4

# %%
import numpy as np
tight_data=[60,70,80]
spread_data=[20,70,120]
print("tight std:",np.std(spread_data))
print("spread std:",np.std(tight_data))
# Out:
# tight std: 40.824829046386306
# spread std: 8.16496580927726

# %%
import random
#stimulation(random prediction
for i in range(5):
  prediction=random.choice(["spam","notspam"])
  print(f"email{i+1}:{prediction}")
# Out:
# email1:notspam
# email2:notspam
# email3:notspam
# email4:spam
# email5:notspam

# %%
import random
#stimulate 10 dice rolls
sample=[random.randint(1,6)
 for i in range(10)]
print("sample rolls:",sample)
print("sample mean:",sum(sample)/len(sample))
# Out:
# sample rolls: [4, 6, 1, 2, 3, 3, 1, 4, 3, 5]
# sample mean: 3.2
